# %%
# !pip install selenium

# %%
from selenium import webdriver
import pandas as pd
import time

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.olx.com.ec/autos_c378')

# %%
time.sleep(3)
autos = driver.find_elements_by_xpath('.//li[@data-aut-id="itemBox"]')

# %%
time.sleep(3)
nombres = []
precios = []
detalles = []
for auto in autos:
    nombre = auto.find_element_by_xpath('.//span[@data-aut-id="itemTitle"]').text
    precio = auto.find_element_by_xpath('.//span[@data-aut-id="itemPrice"]').text
    detalle = auto.find_element_by_xpath('.//span[@data-aut-id="itemDetails"]').text
    nombres.append(nombre)
    precios.append(precio)
    detalles.append(detalle)

# %%
df = pd.DataFrame(list(zip(nombres, precios, detalles)), columns=['Nombre', 'Precio', 'Detalle'])
df
# Out:
#                                                Nombre    Precio  \
# 0                  CHEVROLET D-MAX 2020 CD 2.5 CD 4X4  $ 35,598
# 1                         Mazda 3 año 2013. Mecánico.  $ 13,800
# 2              SPARK GT PREMIER AC 1.2 5P 2020 4X2 TM  $ 14,456
# 3                        FORD FUSION 2014 (20.000 KM)  $ 22,000
# 4                         Chevrolet Grand Vitara Full  $ 14,400
# 5                                       Kia Soul 2012  $ 13,200
# 6                          Suzuki Gran Vitara SZ next  $ 15,900
# 7         FIAT STRADA WORKING 1.4 CS 4X2 TM 2014 ROJO  $ 11,900
# 8           KIA PICANTO EX AC 1.2 4P 4X2 TM 2019 ROJO  $ 13,000
# 9   VOLKSWAGEN AMAROK BI TDI PLUS AC 2.0 CD 4X4 TM...  $ 30,400
# 10                    TOYOTA COROLLA 2013 MANUAL FULL  $ 15,300
# 11                                  Toyota Yaris 2019  $ 17,700
# 12          Renault Stepway Nuevo Manual Motor 1600cc  $ 17,023
# 13                  RENAULT Sandero Nuevo Full Equipo  $ 14,620
# ...
